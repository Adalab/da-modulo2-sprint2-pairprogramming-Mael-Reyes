# %%
import mysql.connector
from mysql.connector import errorcode


# Importar librerías para manipulación y análisis de datos
# -----------------------------------------------------------------------
import pandas as pd
import numpy as np

# %%
cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
                              host='127.0.0.1',
                              database='northwind')

print(cnx)
cnx.close()

# %%
# En este código estamos haciendo un try except. Si recordamos esto nos permitía hacer un manejo de los errores, para evitar que nuestro código se pare. Para eso lo que estamos haciendo es
## intenta hacer la conexión son la base de datos de tienda 
try:
  cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
                              host='127.0.0.1',
                              database='northwind')
# en caso de que no lo consigas por que hay algún error entonces ...
except mysql.connector.Error as err:

  # si es un error con la contraseña devuelveme un mensaje de acceso denegado ya que tenemos problemas con la contraseña
  if err.errno == errorcode.ER_ACCESS_DENIED_ERROR:
    print("Something is wrong with your user name or password")
  
  # si el error no tiene que ver con la contraseña, puede ser porque la base de datos no exista, devuelveme un mensaje de que la base de datos no existe
  elif err.errno == errorcode.ER_BAD_DB_ERROR:
    print("Database does not exist")
  
  # si no es por ninguno de los errores anteriores, printeame cual es el error que estoy teniendo en mi conexión
  else:
    print(err)
else:
  cnx.close()

# %%
# conectamos con el servidor
cnx = mysql.connector.connect(
              user='root', password='AlumnaAdalab',
              host='127.0.0.1',
              database='northwind'
)

# creamos el servidor
mycursor = cnx.cursor()

# ejecutamos la query para ver las tablas de la BBDD que hemos indicado en la conexión
mycursor.execute("SELECT * FROM customers")

myresult = mycursor.fetchall()

print(myresult)
# Out:
# [('ALFKI', 'Alfreds Futterkiste', 'Maria Anders', 'Sales Representative', 'Obere Str. 57', 'Berlin', '', '12209', 'Germany', '030-0074321', '030-0076545'), ('ANATR', 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Owner', 'Avda. de la Constituci?n 2222', 'M?xico D.F.', '', '05021', 'Mexico', '(5) 555-4729', '(5) 555-3745'), ('ANTON', 'Antonio Moreno Taquer?a', 'Antonio Moreno', 'Owner', 'Mataderos  2312', 'M?xico D.F.', '', '05023', 'Mexico', '(5) 555-3932', ''), ('AROUT', 'Around the Horn', 'Thomas Hardy', 'Sales Representative', '120 Hanover Sq.', 'London', '', 'WA1 1DP', 'UK', '(171) 555-7788', '(171) 555-6750'), ('BERGS', 'Berglunds snabbk?p', 'Christina Berglund', 'Order Administrator', 'Berguvsv?gen  8', 'Lule?', '', 'S-958 22', 'Sweden', '0921-12 34 65', '0921-12 34 67'), ('BLAUS', 'Blauer See Delikatessen', 'Hanna Moos', 'Sales Representative', 'Forsterstr. 57', 'Mannheim', '', '68306', 'Germany', '0621-08460', '0621-08924'), ('BLONP', 'Blondesddsl p?re et fils', 'Fr?d
# ...

# %%
cnx = mysql.connector.connect(
              user='root', password='AlumnaAdalab',
              host='127.0.0.1',
              database='northwind'
)

# Crear un cursor
cursor = cnx.cursor()

# Ejecutar la consulta SQL
consulta = "SELECT COLUMN_NAME FROM information_schema.columns WHERE TABLE_NAME = 'customers';"
cursor.execute(consulta)

# Obtener los resultados
resultados = cursor.fetchall()

# Mostrar los nombres de las columnas
print("Nombres de las columnas de la tabla 'customers':")
for columna in resultados:
    print(columna[0])

# Cerrar el cursor y la conexión
cursor.close()
cnx.close()
# Out:
# Nombres de las columnas de la tabla 'customers':
# address
# name
# address
# city
# company_name
# contact_name
# contact_title
# country
# customer_id
# fax
# phone
# postal_code
# region
# address_line1
# address_line2
# city
# contact_first_name
# contact_last_name
# country
# credit_limit
# customer_name
# customer_number
# phone
# postal_code
# sales_rep_employee_number
# state

# %% [markdown]
# Seleccionar todo de la tabla "customers" donde "country" sea "USA" o "Germany". Almacenar los resultados en una variable

# %%
cnx = mysql.connector.connect(
              user='root', password='AlumnaAdalab',
              host='127.0.0.1',
              database='northwind'
)

# Crear un cursor
cursor = cnx.cursor()

# Ejecutar la consulta SQL
pais = """SELECT * FROM customers WHERE country in ("USA", "Germany") ;"""
cursor.execute(pais)

# Obtener los resultados
resultados = cursor.fetchall()

for x in resultados:
    print(x)

# Cerrar el cursor y la conexión
cursor.close()
cnx.close()
# Out:
# ('ALFKI', 'Alfreds Futterkiste', 'Maria Anders', 'Sales Representative', 'Obere Str. 57', 'Berlin', '', '12209', 'Germany', '030-0074321', '030-0076545')
# ('BLAUS', 'Blauer See Delikatessen', 'Hanna Moos', 'Sales Representative', 'Forsterstr. 57', 'Mannheim', '', '68306', 'Germany', '0621-08460', '0621-08924')
# ('DRACD', 'Drachenblut Delikatessen', 'Sven Ottlieb', 'Order Administrator', 'Walserweg 21', 'Aachen', '', '52066', 'Germany', '0241-039123', '0241-059428')
# ('FRANK', 'Frankenversand', 'Peter Franken', 'Marketing Manager', 'Berliner Platz 43', 'M?nchen', '', '80805', 'Germany', '089-0877310', '089-0877451')
# ('GREAL', 'Great Lakes Food Market', 'Howard Snyder', 'Marketing Manager', '2732 Baker Blvd.', 'Eugene', 'OR', '97403', 'USA', '(503) 555-7555', '')
# ('HUNGC', 'Hungry Coyote Import Store', 'Yoshi Latimer', 'Sales Representative', 'City Center Plaza 516 Main St.', 'Elgin', 'OR', '97827', 'USA', '(503) 555-6874', '(503) 555-2376')
# ...

# %%
import pandas as pd

# %% [markdown]
# Convertir los resultados del ejercicio anterior en un Dataframe (no od olvidéis de poner el nombre a las columnas en el orden correcto).

# %%
cnx = mysql.connector.connect(
              user='root', password='AlumnaAdalab',
              host='127.0.0.1',
              database='northwind'
)

# Crear un cursor
cursor = cnx.cursor()

# Ejecutar la consulta SQL
pais = """SELECT * FROM customers WHERE country in ("USA", "Germany") ;"""
cursor.execute(pais)

# Obtener los resultados
resultados = cursor.fetchall()

df = pd.DataFrame(resultados,columns=["customer_id", "company_name", "contact_name", "contact_title", "address", "city", "region", "postal_code", "country", "phone", "fax"])


cnx.close()

# %%
df.head(10)
# Out:
#   customer_id                company_name    contact_name  \
# 0       ALFKI         Alfreds Futterkiste    Maria Anders
# 1       BLAUS     Blauer See Delikatessen      Hanna Moos
# 2       DRACD    Drachenblut Delikatessen    Sven Ottlieb
# 3       FRANK              Frankenversand   Peter Franken
# 4       GREAL     Great Lakes Food Market   Howard Snyder
# 5       HUNGC  Hungry Coyote Import Store   Yoshi Latimer
# 6       KOENE             K?niglich Essen   Philip Cramer
# 7       LAZYK        Lazy K Kountry Store      John Steel
# 8       LEHMS         Lehmanns Marktstand  Renate Messner
# 9       LETSS           Let's Stop N Shop    Jaime Yorres
#
#           contact_title                         address            city  \
# 0  Sales Representative                   Obere Str. 57          Berlin
# 1  Sales Representative                  Forsterstr. 57        Mannheim
# 2   Order Administrator                    Walserweg 21          Aachen
# ...

# %%
df.tail(10)
# Out:
#    customer_id                       company_name        contact_name  \
# 14       QUICK                         QUICK-Stop         Horst Kloss
# 15       RATTC         Rattlesnake Canyon Grocery        Paula Wilson
# 16       SAVEA                 Save-a-lot Markets      Jose Pavarotti
# 17       SPLIR              Split Rail Beer & Ale  Art Braunschweiger
# 18       THEBI                     The Big Cheese           Liz Nixon
# 19       THECR                    The Cracker Box            Liu Wong
# 20       TOMSP                 Toms Spezialit?ten       Karin Josephs
# 21       TRAIH  Trail's Head Gourmet Provisioners      Helvetius Nagy
# 22       WANDK                  Die Wandernde Kuh         Rita M?ller
# 23       WHITC               White Clover Markets      Karl Jablonski
#
#                      contact_title                      address         city  \
# 14              Accounting Manager             Taucherstra?e 10    Cunewalde
# ...

# %%
df.sample(5)
# Out:
#    customer_id             company_name         contact_name  \
# 18       THEBI           The Big Cheese            Liz Nixon
# 19       THECR          The Cracker Box             Liu Wong
# 4        GREAL  Great Lakes Food Market        Howard Snyder
# 13       OTTIK       Ottilies K?seladen  Henriette Pfalzheim
# 6        KOENE          K?niglich Essen        Philip Cramer
#
#           contact_title                   address         city region  \
# 18    Marketing Manager  89 Jefferson Way Suite 2     Portland     OR
# 19  Marketing Assistant       55 Grizzly Peak Rd.        Butte     MT
# 4     Marketing Manager          2732 Baker Blvd.       Eugene     OR
# 13                Owner        Mehrheimerstr. 369         K?ln
# 6       Sales Associate             Maubelstr. 90  Brandenburg
#
#    postal_code  country           phone             fax
# 18       97201      USA  (503) 555-3612
# 19       59801      USA  (406) 555-5834  (406) 555-8083
# ...

# %%
df.isnull().sum()
# Out:
# customer_id      0
# company_name     0
# contact_name     0
# contact_title    0
# address          0
# city             0
# region           0
# postal_code      0
# country          0
# phone            0
# fax              0
# dtype: int64

# %%
df.describe()
# Out:
#        customer_id         company_name  contact_name         contact_title  \
# count           24                   24            24                    24
# unique          24                   24            24                     9
# top          ALFKI  Alfreds Futterkiste  Maria Anders  Sales Representative
# freq             1                    1             1                     7
#
#               address      city region postal_code country        phone fax
# count              24        24     24          24      24           24  24
# unique             24        23      9          24       2           24  18
# top     Obere Str. 57  Portland              12209     USA  030-0074321
# freq                1         2     11           1      13            1   7

# %%
df.columns
# Out:
# Index(['customer_id', 'company_name', 'contact_name', 'contact_title',
#        'address', 'city', 'region', 'postal_code', 'country', 'phone', 'fax'],
#       dtype='object')
